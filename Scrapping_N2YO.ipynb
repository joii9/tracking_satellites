# %%
import requests
from bs4 import BeautifulSoup as bs

page = requests.get('https://www.n2yo.com/satellite/?s=99005#results') #39035
print(page)
# Out:
# <Response [200]>

# %%
print(page.content)
# Out:
# b'\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<HEAD>\r\n<TITLE>SL-1 R/B Satellite details 1957-001A NORAD 1</TITLE>\r\n<meta name="viewport" content="width=device-width, initial-scale=1" />\r\n<meta content="text/html; charset=UTF-8" http-equiv="content-type">\r\n<link rel="stylesheet" href="/css/style.css" type="text/css">\r\n<script src="/js/jquery-1.11.js"></script>\r\n<script type="text/javascript" src="/js/timezone.js?1749511598"></script>\r\n<script src="/js/tooltip.js" type="text/javascript"></script>\r\n<script src="/js/tooltip-items.js" type="text/javascript"></script>\r\n\r\n<meta property="og:url" content="https://www.n2yo.com//satellite/?s=1"/>\r\n<meta property="og:title" content="Technical details for satellite SL-1 R/B"/>\r\n<meta property="og:image" content="https://www.n2yo.com/img/n2yo-circle-fb.png"/>\r\n<meta property="og:site_name" content="N2YO.com - Real Time Satellite Tracking and Predictions"/>\r\n<meta property="og:type" content="website"/>\r\n<meta property="og:description" content="Sputnik 1 was the first artificial satellite to be put into orbit, on October 4, 1957. Coming at the height of the Cold War, the launching of Sputnik caught the West by surprise, and in the U...."/>\r\n\r\n<META name="keywords" content="SL-1 R/B, 1957-001A, 1, satellite tracking, passes, prediction, satellite database">\r\n<META name="description" content="Technical details about the SL-1 R/B (1957-001A or NORAD 1) satellite. SL-1 R/B can be selected for live tracking or to see the passes visible from your location, if applicable">\r\n\r\n\r\n\r\n</HEAD>\r\n<body>\r\n<script type=\'text/javascript\' src="/js/passes.js"></script> \r\n<script>\r\nvar startPass = null;\r\nvar endPass = null;\r\nvar timer;\r\nvar issid = 25544;\r\nvar lat = 37.517979;\r\nvar lng = -121.929488;\r\ngo();\r\n</script>\r\n\r\n<!-- \r\n<script type=\'text/javascript\'>\r\n  var googletag = googletag || {};\r\n  googletag.cmd = googletag.cmd || [];\r\n  (function() {\r\n    var gads = document.createElement(\'script\');\r\n    gads.async = true;\r\n    gads.type = \'text/javascript\';\r\n    var useSSL = \'https:\' == document.location.protocol;\r\n    gads.src = (useSSL ? \'https:\' : \'http:\') +\r\n      \'//www.googletagservices.com/tag/js/gpt.js\';\r\n    var node = document.getElementsByTagName(\'script\')[0];\r\n    node.parentNode.insertBefore(gads, node);\r\n  })();\r\n</script> -->\r\n\r\n<!-- Google tag Analytics (gtag.js) -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-QZGWPSKPV5"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'G-QZGWPSKPV5\');\r\n</script>\r\n\r\n<script type=\'text/javascript\'>\r\n  googletag.cmd.push(function() {\r\n    googletag.defineSlot(\'/31043081/n2yo-header\', [728, 90], \'div-gpt-ad-1438712706402-0\').addService(googletag.pubads());\r\n    googletag.pubads().enableSingleRequest();\r\n    googletag.enableServices();\r\n  });\r\n</script>\r\n\r\n\r\n<div id="headercontainer" style="overflow: auto; zoom: 1">\r\n<table style="width:100%;font-size:14px">\r\n<tr>\r\n<td>\r\n\t<div id="logo">\r\n\t\t<a href="/"><img src="/img/n2yologo.png" width="200" height="39" border="0" alt="n2yo.com"/></a>\r\n\t\t<div class="fb-like" data-href="https://www.facebook.com/n2yodotcom" data-send="false" data-layout="button_count" data-width="100" data-show-faces="false" data-font="tahoma"></div>\r\n\t\t<g:plusone></g:plusone>\r\n\r\n\t</div>\r\n<span id = "headermessage" style="background-color:#ffffca;border:1px dashed #cacaba;width:300px;">\r\n\r\n\tTracking <b><span style="color:#d50000">30659</span></b> objects as of 9-Jun-2025\t<br/><a href="/space-station/">\r\n\tHD Live streaming from Space Station</a>\r\n\t<br/>\r\n\t<script src="/js/satellite-js/dist/satellite.min.js"></script> \r\n<link rel="stylesheet" href="/css/odometer-theme-car.css" />\r\n<script src="/js/odometer.js"></scri ...

# %% [markdown]
# It is possible make an slice over a bytes object as it is page.content

# %%
print(page.content[-5:])
# Out:
# b'ml>\r\n'

# %%
soup = bs(page.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <head>
# <title> Satellite details  NORAD 99005</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link href="/css/style.css" rel="stylesheet" type="text/css"/>
# <script src="/js/jquery-1.11.js"></script>
# <script src="/js/timezone.js?1749680422" type="text/javascript"></script>
# <script src="/js/tooltip.js" type="text/javascript"></script>
# <script src="/js/tooltip-items.js" type="text/javascript"></script>
# <meta content="https://www.n2yo.com//satellite/?s=99005" property="og:url">
# <meta content="Technical details for satellite " property="og:title"/>
# <meta content="https://www.n2yo.com/img/n2yo-circle-fb.png" property="og:image"/>
# <meta content="N2YO.com - Real Time Satellite Tracking and Predictions" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="..." property="og:description"/>
# <meta content=", , 99005, satellite tracking, passes, prediction, satellite database" name="keywords"/>
# <meta content="Technical details about the  ( or NORAD 99005) satellite.  can be selected for live tracking or to see the passes visible from your location, if applicable" name="description"/>
# </meta></head>
# <body>
# <script src="/js/passes.js" type="text/javascript"></script>
# <script>
# var startPass = null;
# var endPass = null;
# var timer;
# var issid = 25544;
# var lat = 37.54827;
# var lng = -121.98857;
# go();
# </script>
# <!--
# <script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script> -->
# <!-- Google tag Analytics (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-QZGWPSKPV5"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-QZGWPSKPV5');
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/31043081/n2yo-header', [728, 90], 'div-gpt-ad-1438712706402-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <div id="headercontainer" style="overflow: auto; zoom: 1">
# <table style="width:100%;font-size:14px">
# <tr>
# <td>
# <div id="logo">
# <a href="/"><img alt="n2yo.com" border="0" height="39" src="/img/n2yologo.png" width="200"/></a>
# <div class="fb-like" data-font="tahoma" data-href="https://www.facebook.com/n2yodotcom" data-layout="button_count" data-send="false" data-show-faces="false" data-width="100"></div>
# <g:plusone></g:plusone>
# </div>
# <span id="headermessage" style="background-color:#ffffca;border:1px dashed #cacaba;width:300px;">
#
# 	Tracking <b><span style="color:#d50000">30705</span></b> objects as of 11-Jun-2025	<br/><a href="/space-station/">
# 	HD Live streaming from Space Station</a>
# <br/>
# <script src="/js/satellite-js/dist/satellite.min.js"></script>
# <link href="/css/odometer-theme-car.css" rel="stylesheet">
# <script src="/js/odometer.js"></script>
# <style>
# .odometer {
#     font-size: 16px;
# }
# </style>
# <span id="up"><div class="odometer" id="odometer"></div> objects crossing your sky now
# <script>
# var items;
# if (!( /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) )) {
#
# 	$.get("/inc/all.php", function(data) {
# 		  items = data.split('\n');
# 		up();
# 	});
# 	setInterval('up()', 5000);
# }
# else
# {
#     document.getElementById("up").style.display='none';
# }
# function up()
# {
# 	  var cnt = 0;
# 	  for(var i=0;i<items.length;i++)
# 	  {
# 		var line = items[i];
# 		if(line[0]=="1")
# 		  {
# 			var satid = parseInt(line.substr(2,5));
# 			var line1 = items[i];
# 			var line2 = items[i+1];
# 			var satrec = satellite.twoline2satrec(line1, line2);
# 			var now = new Date();
#
#
# 			var positionAndVelocity = satellite.propagate(
# 				satrec,
# 				now.getUTCFullYear(),
# 				now.getUTCMonth() + 1,
# 				now.getUTCDate(),
# 				now.getUTCHours(),
# 				now.getUTCMinutes(),
# 				now.getUTCSeconds()
# 			);
#
#
#
# 			var positionEci = positionAndVelocity.position,
# 		    velocityEci = positionAndVelocity.velocity;
#
# 			var gmst = satellite.gstimeFromDate(
# 		    now.getUTCFullYear(),
# 		    now.getUTCMonth() + 1,
# 		    now.getUTCDate(),
# 		    now.getUTCHours(),
# 		    now.getUTCMinutes(),
# 		    now.getUTCSeconds()
# 			);
#
# var deg2rad = Math.PI/180;
# var observerGd = {
#     longitude: -121.98857 * deg2rad,
#     latitude: 37.54827 * deg2rad,
#     height: 0
# };
#
# try
# {
#
# 			var positionEcf   = satellite.eciToEcf(positionEci, gmst);
#
# }
# catch (err)
# {
# 												//console.log("Error: " + err);
# }
#
#
#
# 			var lookAngles    = satellite.ecfToLookAngles(observerGd, positionEcf);
#
#
# 		    var dopplerFactor = 0;
# var azimuth   = lookAngles.azimuth,
#     elevation = lookAngles.elevation,
#     rangeSat  = lookAngles.rangeSat;
#
# 			azimuth1 =  azimuth*180/Math.PI;
# 			elevation1 =  elevation*180/Math.PI;
#
#
# 			if(elevation1>10)
# 			  {
# 				cnt++;
# 			  }
#
# 		  }
# 	  }
# 	odometer.innerHTML = cnt;
#
# }
# </script>
# </span>
# </link></span></td>
# <td align="center" valign="top" width="200">
# <!--<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>-->
# <!-- n2yo-com-234x60 -->
# <!--<ins class="adsbygoogle"
#      style="display:inline-block;width:234px;height:60px"
#      data-ad-client="ca-pub-8839140430005838"
#      data-ad-slot="1743584802"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>-->
# <b><span id="countdown" style="display:block"></span></b>
# </td>
# <td align="right" valign="top">
# <form action="/database/#results" method="GET">
# <div align="right" id="searchbox">
# <br/>
# <input id="srcsat" name="q" onfocus='document.getElementById("srcsat").value="";' size="12" style="font-size: 14px; background-color: #FFFFFF;width:140px" type="text" value="Find a satellite..."/>
# <input style="font-size: 12px; background-color:#D8D8D8; color:#000000; margin-right: 6px;" type="submit" value="Search"/>
# <div align="right">
# <a href="https://www.facebook.com/n2yodotcom">N2YO.com on Facebook</a>
#
# 		<a href="/database/">Advanced</a>   </div>
# </div></form>
# </td></tr></table></div>
# <script src="https://apis.google.com/js/plusone.js" type="text/javascript"></script>
#
#
#
#
# <div id="admobiheader">
# <!--
# <script id="mNCC" language="javascript">
#     medianet_width = "468";
#     medianet_height = "60";
#     medianet_crid = "344318977";
#     medianet_versionId = "111299";
#     (function() {
#         var isSSL = 'https:' == document.location.protocol;
#         var mnSrc = (isSSL ? 'https:' : 'http:') + '//contextual.media.net/nmedianet.js?cid=8CUY6IMG3' + (isSSL ? '&https=1' : '');
#         document.write('<scr' + 'ipt type="text/javascript" id="mNSC" src="' + mnSrc + '"></scr' + 'ipt>');
#     })();
#   </script>
# -->
# </div>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3&appId=372896566168367";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <!--
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-8839140430005838",
#           enable_page_level_ads: true
#      });
# </script>
# -->
# <!-- <div style="height:24px;background-color:#ff0000;color:#fff;">
# <center><strong><a href="https://www.n2yo.com/?s=49220" style="color:#fff;visited:#fff;active:#fff;hover:#eee">Track INSPIRATION-4</a></strong></center> -->
#
# <div id="menu">
# <link href="/ddmenu/ddmenu.css" rel="stylesheet" type="text/css"/>
# <script src="/ddmenu/ddmenu.js" type="text/javascript"></script>
# <!--INFOLINKS_OFF-->
# <nav id="ddmenu">
# <div class="menu-icon"></div>
# <ul>
# <li class="no-sub"><a class="top-heading" href="https://www.n2yo.com/">Home</a></li>
# <li>
# <span class="top-heading"><a class="top-heading" href="/satellites/?c=most-popular">Most tracked</a></span>
# <i class="caret"></i>
# <div class="dropdown">
# <div class="dd-inner">
# <div class="column">
# <a href="/satellite/?s=25544">SPACE STATION</a>
# <a href="/satellite/?s=36516">SES 1</a>
# <a href="/satellite/?s=33591">NOAA 19</a>
# <a href="/satellite/?s=29155">GOES 13</a>
# <a href="/satellite/?s=25338">NOAA 15</a>
# <a href="/satellite/?s=28654">NOAA 18</a>
# <a href="/satellite/?s=25994">TERRA</a>
# <a href="/satellite/?s=27424">AQUA</a>
# <a href="/satellite/?s=38771">METOP-B</a>
# <a href="/satellite/?s=37849">SUOMI NPP</a>
# <a href="/satellite/?s=36411">GOES 15</a>
# <a href="/satellite/?s=40967">FOX-1A (AO-85)</a>
# <a href="/satellite/?s=27607">SAUDISAT 1C</a>
# <a href="/satellite/?s=41332">KMS-4</a>
# <a href="/satellite/?s=37820">TIANGONG 1</a>
# <a href="/satellite/?s=40069">METEOR M2</a>
# <a href="/satellite/?s=25657">ASIASAT 3S</a>
# <a href="/satellite/?s=36032">NSS 12</a>
# <a href="/satellite/?s=31135">AGILE</a>
# <a href="/satellite/?s=40147">MEASAT 3B</a>
# <a href="/satellites/?c=most-popular">MORE...</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <span class="top-heading"><a class="top-heading" href="/satellites/?c=latest-launches">Just launched</a></span>
# <i class="caret"></i>
# <div class="dropdown">
# <div class="dd-inner">
# <div class="column">
# <a href="/satellite/?s=64290">SIRIUS XM-10</a>
# <a href="/satellite/?s=64289">USA 546</a>
# <a href="/satellite/?s=64287">HULIANWANG DIGU</a>
# <a href="/satellite/?s=64286">HULIANWANG DIGU</a>
# <a href="/satellite/?s=64285">HULIANWANG DIGU</a>
# <a href="/satellite/?s=64284">HULIANWANG DIGU</a>
# <a href="/satellite/?s=64283">HULIANWANG DIGU</a>
# <a href="/satellite/?s=64282">STARLINK-34381</a>
# <a href="/satellite/?s=64281">STARLINK-34366</a>
# <a href="/satellite/?s=64280">STARLINK-34359</a>
# <a href="/satellite/?s=64279">STARLINK-34377</a>
# <a href="/satellite/?s=64278">STARLINK-34353</a>
# <a href="/satellite/?s=64277">STARLINK-34264</a>
# <a href="/satellite/?s=64276">STARLINK-34350</a>
# <a href="/satellite/?s=64275">STARLINK-34293</a>
# <a href="/satellite/?s=64274">STARLINK-34272</a>
# <a href="/satellite/?s=64273">STARLINK-34334</a>
# <a href="/satellite/?s=64272">STARLINK-34001</a>
# <a href="/satellite/?s=64271">STARLINK-34342</a>
# <a href="/satellite/?s=64270">STARLINK-34219</a>
# <a href="/satellites/?c=latest-launches">MORE...</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <span class="top-heading">Satellites on orbit</span>
# <i class="caret"></i>
# <div class="dropdown">
# <div class="dd-inner">
# <div class="column">
# <h4><a href="/satellites/">CATEGORIES</a></h4>
# <a href="/satellites/?c=2">Int'l Space Station</a>
# <a href="/satellites/?c=54">Chinese Space Station</a>
# <a href="/satellites/?c=1">Brightest</a>
# <a href="/satellites/?c=52">Starlink</a>
# <a href="/satellites/?c=20">GPS Operational</a>
# <a href="/satellites/?c=21">Glonass Operational</a>
# <a href="/satellites/?c=22">Galileo</a>
# <a href="/satellites/?c=35">Beidou</a>
# <a href="/satellites/?c=30">Military</a>
# <a href="/satellites/?c=15">Iridium</a>
# <a href="/satellites/?c=17">Globalstar</a>
# <a href="/satellites/?c=10">Geostationary</a>
# <a href="/satellites/?c=26">Space &amp; Earth Science</a>
# <a href="/satellites/?c=3">Weather</a>
# <a href="/satellites/?c=18">Amateur radio</a>
# <a href="/satellites/">MORE CATEGORIES...</a>
# </div>
# <div class="column">
# <h4><a href="/whats-up/whats-up-now.php">WHAT'S UP?</a></h4>
# <a href="/passes/amateur-radio.php">Amateur radio sat passes</a>
# <a href="/whats-up/?c=20">GPS satellites</a>
# <a href="/whats-up/?c=21">Glonass satellites</a>
# <a href="/whats-up/?c=35">Beidou satellites</a>
# <a href="/whats-up/?c=22">Galileo satellites</a>
# <a href="/whats-up/?c=15">Iridium satellites</a>
# <a href="/whats-up/?c=17">Globalstar satellites</a>
# <!--<a href="/whats-up/whats-up-now.php" style="color:red">What's up in your sky now?</a>-->
# <br/>
# <h4><a href="/database/">FIND A SATELLITE</a></h4>
# <a href="/database/"> SEARCH DATABASE</a>
# <a href="/browse/"> BROWSE BY LAUNCH DATE</a>
# <a href="/satellites/"> BROWSE BY CATEGORY</a>
# <a href="/satellites/?c=&amp;t=country"> BROWSE BY COUNTRY</a>
# </div>
# <div class="column">
# <h4><a href="/satellites?c=&amp;t=country">OWNERS/COUNTRIES</a></h4>
# <a href="/satellites?c=US&amp;t=country"><img border="0" height="15" src="/img/org/us.gif" style="vertical-align: text-bottom" width="20"/> UNITED STATES</a>
# <a href="/satellites?c=CIS&amp;t=country"><img border="0" height="15" src="/img/org/cis.gif" style="vertical-align: text-bottom" width="20"/> CIS (FORMER USSR)</a>
# <a href="/satellites?c=PRC&amp;t=country"><img border="0" height="15" src="/img/org/prc.gif" style="vertical-align: text-bottom" width="20"/> PEOPLE'S REPUBLIC OF CHINA</a>
# <a href="/satellites?c=JPN&amp;t=country"><img border="0" height="15" src="/img/org/jpn.gif" style="vertical-align: text-bottom" width="20"/> JAPAN</a>
# <a href="/satellites?c=ESA&amp;t=country"><img border="0" height="15" src="/img/org/esa.gif" style="vertical-align: text-bottom" width="20"/> EUROPEAN SPACE AGENCY</a>
# <a href="/satellites?c=FR&amp;t=country"><img border="0" height="15" src="/img/org/fr.gif" style="vertical-align: text-bottom" width="20"/> FRANCE</a>
# <a href="/satellites?c=IND&amp;t=country"><img border="0" height="15" src="/img/org/ind.gif" style="vertical-align: text-bottom" width="20"/> INDIA</a>
# <a href="/satellites?c=UK&amp;t=country"><img border="0" height="15" src="/img/org/uk.gif" style="vertical-align: text-bottom" width="20"/> UNITED KINGDOM</a>
# <a href="/satellites?c=CA&amp;t=country"><img border="0" height="15" src="/img/org/ca.gif" style="vertical-align: text-bottom" width="20"/> CANADA</a>
# <a href="/satellites?c=GER&amp;t=country"><img border="0" height="15" src="/img/org/ger.gif" style="vertical-align: text-bottom" width="20"/> GERMANY</a>
# <a href="/satellites?c=&amp;t=country"> MORE OWNERS/COUNTRIES...</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="top-heading" href="/info/?a=22">Alerting tools</a>
# <i class="caret"></i>
# <div class="dropdown right-aligned">
# <div class="dd-inner">
# <div class="column">
# <h4>ALERTING TOOLS</h4>
# <a href="/info/?a=43"><img border="0" src="/ddmenu/phone.png" style="vertical-align: text-bottom" width="16"/> SPACE STATION PREDICTIONS BY VOICE</a>
# <a href="/login/iss-notifications/"><img border="0" src="/ddmenu/alert.png" style="vertical-align: text-bottom" width="16"/> SPACE STATION NOTIFICATION TOOL </a>
# <a href="/info/?a=15"><img border="0" src="/ddmenu/email.png" style="vertical-align: text-bottom" width="16"/> ALERTS BY EMAIL AND SMS</a>
# </div>
# </div>
# </div></li>
# <li>
# <span class="top-heading">More stuff</span>
# <i class="caret"></i>
# <div class="dropdown right-aligned">
# <div class="dd-inner">
# <div class="column">
# <h4>ADDITIONAL INFO</h4>
# <a href="/space-station" style="color:red"><b>HD LIVE STREAMING FROM ISS</b></a>
# <a href="/news/read.php?p=0">SATELLITE NEWS</a>
# <a href="/about/?a=donation">MAKE A DONATION</a>
# <a href="https://www.facebook.com/n2yodotcom">N2YO.COM ON FACEBOOK</a>
# <a href="/about/?a=links">EXTERNAL LINKS</a>
# <a href="/about/?a=faq">FAQ</a>
# <a href="/about/?a=feedback">CONTACT/FEEDBACK</a>
# <a href="/about/?a=privacy">PRIVACY POLICY</a>
# <a href="/about/?a=terms">TERMS OF USE</a>
# </div>
# <div class="column">
# <h4>USER PREFERENCES</h4>
# <a href="https://www.n2yo.com/login/edit/">SIGN IN</a> <a href="https://www.n2yo.com/login/edit/">EDIT/CHANGE YOUR LOCATION</a>
# <br/>
# <h4>SITE OWNERS</h4>
# <a href="/widgets/">WIDGETS FOR YOUR PAGE</a>
# <a href="/api/">API ACCESS</a>
# <br/>
# <!-- <h4>MOBILE APPS</h4>
#                     <a href="http://southernstars.com/products/"  style="color:red"><strong>Orbitrack</strong> - <b>NEW</b> (iOS and Android)</a> -->
# </div>
# </div>
# </div>
# </li>
# <li class="no-sub"><a class="top-heading" href="https://www.n2yo.com/login/edit/">Sign in</a></li>
# </ul>
# </nav>
# <!--INFOLINKS_ON-->
# </div>
# <table id="tabsatellite" width="100%">
# <tr>
# <td class="hidecell" style="width:160px">
# <script id="mNCC" language="javascript">
#     medianet_width = "160";
#     medianet_height = "600";
#     medianet_crid = "515138167";
#     medianet_versionId = "111299";
#     (function() {
#         var isSSL = 'https:' == document.location.protocol;
#         var mnSrc = (isSSL ? 'https:' : 'http:') + '//contextual.media.net/nmedianet.js?cid=8CUY6IMG3' + (isSSL ? '&https=1' : '');
#         document.write('<scr' + 'ipt type="text/javascript" id="mNSC" src="' + mnSrc + '"></scr' + 'ipt>');
#     })();
#   </script>
# </td>
# <td>
# <div id="satinfo">
# <h1></h1>
# <p class="spaced">
# </p>
# <br/>
# <b>NORAD ID</b>:  <a class="showTip noradid" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Int'l Code</b>:  <a class="showTip intlcode" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Perigee</b>: 580.7 km <a class="showTip perigee" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Apogee</b>: 587.7 km <a class="showTip apogee" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Inclination</b>: 70.0 ° <a class="showTip inclination" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Period</b>: 96.2 minutes <a class="showTip period" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Semi major axis</b>: 6955 km <a class="showTip semimajoraxis" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>RCS</b>: Unknown <a class="showTip rcs" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Launch date</b>: <a href="/browse/?y=1970&amp;m=1">January 1, 1970</a>
# <br/><b>Source</b>:  ()
# 			<br/><b>Launch site</b>:  ()
#
#
#
#
#
#
#
#
# 									<br/>
# </div>
# <div id="adsatellitepage">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Responsive bottom -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-8839140430005838" data-ad-format="auto" data-ad-slot="6966096404" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
# <div id="satgraphics">
# <table id="tabtracking">
# <tr>
# <td class="tabheader">
# 		Your satellite tracking list
# 		</td>
# </tr>
# <tr>
# <td>
# <center>
# <form method="POST" name="addsat">
# <input name="satid" type="hidden" value="99005"/>
# <input name="satname" type="hidden" value=""/>
# <!--<a href='javascript:document.addsat.submit()'>Add  on your tracking list</a>-->
# <input class="sButton" onclick="javascript:document.addsat.submit()" type="button" value="Add  on your tracking list">
# </input></form>
# <form method="POST" name="multisat">
# Your tracking list is empty
#   <input name="remove" type="hidden">
# </input></form>
# <script>
# function doit(n)
# {
#  document.multisat.remove.value=n;
#  document.multisat.submit();
# }
# </script> </center>
# </td>
# </tr>
# </table>
# <br/>
# <div id="medianetsatellite">
# <!--<center>
# <a href="//thegreatcoursesplus.7eer.net/c/379891/310092/3896"><img src="//a.impactradius-go.com/display-ad/3896-310092" border="0" alt="" width="300" height="250"/></a><img height="0" width="0" src="//thegreatcoursesplus.7eer.net/i/379891/310092/3896" style="position:absolute;visibility:hidden;" border="0" />
# </center>-->
# </div>
# <center>
# <script>
# 			var norad_n2yo = '99005';
# 			var size_n2yo = 'small';
# 			var allpasses_n2yo = '1';
# 			var map_n2yo = '2';
# 		</script>
# <script src="https://www.n2yo.com/js/widget-tracker.js" type="text/javascript"></script>
# </center>
# <br/>
# <center><script type="text/javascript">
#     google_ad_client = "ca-pub-8839140430005838";
#     google_ad_slot = "4683736009";
#     google_ad_width = 320;
#     google_ad_height = 100;
# </script>
# <!-- 320x100 live streaming -->
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script></center>
# </div>
# <br/>
# <br/><a href="https://nssdc.gsfc.nasa.gov/nmc/spacecraft/display.action?id=" target="_blank">NASA's NSSDC Master Catalog</a>
# <a class="showTip nssdc" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/>
# <br/>
# <b>Two Line Element Set (TLE):</b> <a class="showTip tle" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <div id="tle">
# <pre>
# 1 99005U 25576B   25140.91850249 0.00000000  00000-0  00000-0 0    01
# 2 99005  69.9910 173.0783 0005000 340.2847  19.7153 14.96712050    02
# </pre>
# 		Source of the keplerian elements: 		<br/><br/>
# </div>
# </td>
# </tr>
# </table>
# <!-- footer -->
# <div id="footer">
# <table id="footer">
# <!-- Other links-->
# <tr>
# <td align="center">
# <a href="/about/?a=links">Links</a>  <a href="/about/?a=terms">Terms of Use</a>  <a href="/about/?a=privacy">Privacy Policy</a>  <a href="/about/?a=feedback">Contact Us</a>
# <br/>Copyright © N2YO.com. All rights reserved
# <!--<br/><a href="http://www.itprostar.com">Developed by ITPROSTAR</a>-->
# <br/><br/><!-- AddThis Button BEGIN -->
# <a class="addthis_button" href="https://www.addthis.com/bookmark.php?v=250&amp;username=xa-4bfedf760e3dd1ee"><img alt="Bookmark and Share" height="16" src="https://s7.addthis.com/static/btn/v2/lg-share-en.gif" style="border:0" width="125"/></a><script src="https://s7.addthis.com/js/250/addthis_widget.js#username=xa-4bfedf760e3dd1ee" type="text/javascript"></script>
# <!-- AddThis Button END -->
# </td>
# </tr>
# </table>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-330684-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <!--<script type="text/javascript">
#     var infolink_pid = 1099291;
#     var infolink_wsid = 0;
# </script>
# <script type="text/javascript" src="http://resources.infolinks.com/js/infolinks_main.js"></script>-->
# </div>
# <!--
# -->
# </body>

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'DEFAULT_INTERESTING_STRING_TYPES',
#  'EMPTY_ELEMENT_EVENT',
#  'END_ELEMENT_EVENT',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'START_ELEMENT_EVENT',
#  'STRING_ELEMENT_EVENT',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_clone',
#  '_decode_markup',
#  '_event_stream',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_format_tag',
#  '_indent_string',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_markup_is_url',
#  '_markup_resembles_filename',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'builder',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contains_replacement_characters',
#  'contents',
#  'css',
#  'currentTag',
#  'current_data',
#  'declared_html_encoding',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'default',
#  'descendants',
#  'element_classes',
#  'encode',
#  'encode_contents',
#  'endData',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'formatter_for_name',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'handle_data',
#  'handle_endtag',
#  'handle_starttag',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'interesting_string_types',
#  'isSelfClosing',
#  'is_empty_element',
#  'is_xml',
#  'known_xml',
#  'markup',
#  'name',
#  'namespace',
#  'new_string',
#  'new_tag',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'object_was_parsed',
#  'open_tag_counter',
#  'original_encoding',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parse_only',
#  'parserClass',
#  'parser_class',
#  'popTag',
#  'prefix',
#  'preserve_whitespace_tag_stack',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'pushTag',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'reset',
#  'select',
#  'select_one',
#  'self_and_descendants',
#  'setup',
#  'smooth',
#  'string',
#  'string_container',
#  'string_container_stack',
#  'strings',
#  'stripped_strings',
#  'tagStack',
#  'text',
#  'unwrap',
#  'wrap']

# %%
pre_tags = soup.find("pre")
print(pre_tags)
# Out:
# <pre>
# 1 99005U 25576B   25140.91850249 0.00000000  00000-0  00000-0 0    01
# 2 99005  69.9910 173.0783 0005000 340.2847  19.7153 14.96712050    02
# </pre>

# %%
import requests
from bs4 import BeautifulSoup as bs


def getting_tle(i):
    page = requests.get('https://www.n2yo.com/satellite/?s='+str(i)+'#results')
    soup = bs(page.text, 'html.parser')
    pre_tags = soup.find("pre")
    str_pre_tags= str(pre_tags)
    print(str_pre_tags[7:-7])
    if len(str_pre_tags[7:-7]) > 15:
        textfile= open("C:\\Users\\Joel\\Documents\\Python\\email\\tle_extended.txt", "a")
        textfile.write(str_pre_tags[7:-7])
        textfile.close()

# %%
for i in range (1, 100000):
    print(i)
    getting_tle(i)
# Out:
# 100000
#
#
# 100001
#
#
# 100002
#
#
# 100003
#
#
# 100004
#
#
# 100005
#
#
# 100006
#
#
# 100007
#
#
# 100008
#
#
# 100009
#
#
# 100010
#
#
# 100011
#
#
# 100012
#
#
# 100013
#
#
# 100014
#
#
# 100015
#
#
# 100016
#
#
# 100017
#
#
# 100018
#
#
# 100019
#
#
# 100020
#
#
# 100021
#
#
# 100022
#
#
# 100023
#
#
# 100024
#
#
# 100025
#
#
# 100026
#
#
# 100027
#
#
# 100028
#
#
# 100029
#
#
# 100030
#
#
# 100031
#
#
# 100032
#
#
# 100033
#
#
# 100034
#
#
# 100035
#
#
# 100036
#
#
# 100037
#
#
# 100038
#
#
# 100039
#
#
# 100040
#
#
# 100041
#
#
# 100042
#
#
# 100043
#
#
# 100044
#
#
# 100045
#
#
# 100046
#
#
# 100047
#
#
# 100048
#
#
# 100049
#
#
# 100050
#
#
# 100051
#
#
# 100052
#
#
# 100053
#
#
# 100054
#
#
# 100055
#
#
# 100056
#
#
# 100057
#
#
# 100058
#
#
# 100059
#
#
# 100060
#
#
# 100061
#
#
# 100062
#
#
# 100063
#
#
# 100064
#
#
# 100065
#
#
# 100066
#
#
# 100067
#
#
# 100068
#
#
# 100069
#
#
# 100070
#
#
# 100071
#
#
# 100072
#
#
# 100073
#
#
# 100074
#
#
# 100075
#
#
# 100076
#
#
# 100077
#
#
# 100078
#
#
# 100079
#
#
# 100080
#
#
# 100081
#
#
# 100082
#
#
# 100083
#
#
# 100084
#
#
# 100085
#
#
# 100086
#
#
# 100087
#
#
# 100088
#
#
# 100089
#
#
# 100090
#
#
# 100091
#
#
# 100092
#
#
# 100093
#
#
# 100094
#
#
# 100095
#
#
# 100096
#
#
# 100097
#
#
# 100098
#
#
# 100099
#
#
# 100100
#
#
# 100101
#
#
# 100102
#
#
# 100103
#
#
# 100104
#
#
# 100105
#
#
# 100106
#
#
# 100107
#
#
# 100108
#
#
# 100109
#
#
# 100110
#
#
# 100111
#
#
# 100112
#
#
# 100113
#
#
# 100114
#
#
# 100115
#
#
# 100116
#
#
# 100117
#
#
# 100118
#
#
# 100119
#
#
# 100120
#
#
# 100121
#
#
# 100122
#
#
# 100123
#
#
# 100124
#
#
# 100125
#
#
# 100126
#
#
# 100127
#
#
# 100128
#
#
# 100129
#
#
# 100130
#
#
# 100131
#
#
# 100132
#
#
# 100133
#
#
# 100134
#
#
# 100135
#
#
# 100136
#
#
# 100137
#
#
# 100138
#
#
# 100139
#
#
# 100140
#
#
# 100141
#
#
# 100142
#
#
# 100143
#
#
# 100144
#
#
# 100145
#
#
# 100146
#
#
# 100147
#
#
# 100148
#
#
# 100149
#
#
# 100150
#
#
# 100151
#
#
# 100152
#
#
# 100153
#
#
# 100154
#
#
# 100155
#
#
# 100156
#
#
# 100157
#
#
# 100158
#
#
# 100159
#
#
# 100160
#
#
# 100161
#
#
# 100162
#
#
# 100163
#
#
# 100164
#
#
# 100165
#
#
# 100166
#
#
# 100167
#
#
# 100168
#
#
# 100169
#
#
# 100170
#
#
# 100171
#
#
# 100172
#
#
# 100173
#
#
# 100174
#
#
# 100175
#
#
# 100176
#
#
# 100177
#
#
# 100178
#
#
# 100179
#
#
# 100180
#
#
# 100181
#
#
# 100182
#
#
# 100183
#
#
# 100184
#
#
# 100185
#
#
# 100186
#
#
# 100187
#
#
# 100188
#
#
# 100189
#
#
# 100190
#
#
# 100191
#
#
# 100192
#
#
# 100193
#
#
# 100194
#
#
# 100195
#
#
# 100196
#
#
# 100197
#
#
# 100198
#
#
# 100199
#
#
# 100200
#
#
# 100201
#
#
# 100202
#
#
# 100203
#
#
# 100204
#
#
# 100205
#
#
# 100206
#
#
# 100207
#
#
# 100208
#
#
# 100209
#
#
# 100210
#
#
# 100211
#
#
# 100212
#
#
# 100213
#
#
# 100214
#
#
# 100215
#
#
# 100216
#
#
# 100217
#
#
# 100218
#
#
# 100219
#
#
# 100220
#
#
# 100221
#
#
# 100222
#
#
# 100223
#
#
# 100224
#
#
# 100225
#
#
# 100226
#
#
# 100227
#
#
# 100228
#
#
# 100229
#
#
# 100230
#
#
# 100231
#
#
# 100232
#
#
# 100233
#
#
# 100234
#
#
# 100235
#
#
# 100236
#
#
# 100237
#
#
# 100238
#
#
# 100239
#
#
# 100240
#
#
# 100241
#
#
# 100242
#
#
# 100243
#
#
# 100244
#
#
# 100245
#
#
# 100246
#
#
# 100247
#
#
# 100248
#
#
# 100249
#
#
# 100250
#
#
# 100251
#
#
# 100252
#
#
# 100253
#
#
# 100254
#
#
# 100255
#
#
# 100256
#
#
# 100257
#
#
# 100258
#
#
# 100259
#
#
# 100260
#
#
# 100261
#
#
# 100262
#
#
# 100263
#
#
# 100264
#
#
# 100265
#
#
# 100266
#
#
# 100267
#
#
# 100268
#
#
# 100269
#
#
# 100270
#
#
# 100271
#
#
# 100272
#
#
# 100273
#
#
# 100274
#
#
# 100275
#
#
# 100276
#
#
# 100277
#
#
# 100278
#
#
# 100279
#
#
# 100280
#
#
# 100281
#
#
# 100282
#
#
# 100283
#
#
# 100284
#
#
# 100285
#
#
# 100286
#
#
# 100287
#
#
# 100288
#
#
# 100289
#
#
# 100290
#
#
# 100291
#
#
# 100292
#
#
# 100293
#
#
# 100294
#
#
# 100295
#
#
# 100296
#
#
# 100297
#
#
# 100298
#
#
# 100299
#
#
# 100300
#
#
# 100301
#
#
# 100302
#
#
# 100303
#
#
# 100304
#
#
# 100305
#
#
# 100306
#
#
# 100307
#
#
# 100308
#
#
# 100309
#
#
# 100310
#
#
# 100311
#
#
# 100312
#
#
# 100313
#
#
# 100314
#
#
# 100315
#
#
# 100316
#
#
# 100317
#
#
# 100318
#
#
# 100319
#
#
# 100320
#
#
# 100321
#
#
# 100322
#
#
# 100323
#
#
# 100324
#
#
# 100325
#
#
# 100326
#
#
# 100327
#
#
# 100328
#
#
# 100329
#
#
# 100330
#
#
# 100331
#
#
# 100332
#
#
# 100333
#
#
# 100334
#
#
# 100335
#
#
# 100336
#
#
# 100337
#
#
# 100338
#
#
# 100339
#
#
# 100340
#
#
# 100341
#
#
# 100342
#
#
# 100343
#
#
# 100344
#
#
# 100345
#
#
# 100346
#
#
# 100347
#
#
# 100348
#
#
# 100349
#
#
# 100350
#
#
# 100351
#
#
# 100352
#
#
# 100353
#
#
# 100354
#
#
# 100355
#
#
# 100356
#
#
# 100357
#
#
# 100358
#
#
# 100359
#
#
# 100360
#
#
# 100361
#
#
# 100362
#
#
# 100363
#
#
# 100364
#
#
# 100365
#
#
# 100366
#
#
# 100367
#
#
# 100368
#
#
# 100369
#
#
# 100370
#
#
# 100371
#
#
# 100372
#
#
# 100373
#
#
# 100374
#
#
# 100375
#
#
# 100376
#
#
# 100377
#
#
# 100378
#
#
# 100379
#
#
# 100380
#
#
# 100381
#
#
# 100382
#
#
# 100383
#
#
# 100384
#
#
# 100385
#
#
# 100386
#
#
# 100387
#
#
# 100388
#
#
# 100389
#
#
# 100390
#
#
# 100391
#
#
# 100392
#
#
# 100393
#
#
# 100394
#
#
# 100395
#
#
# 100396
#
#
# 100397
#
#
# 100398
#
#
# 100399
#
#
# 100400
#
#
# 100401
#
#
# 100402
#
#
# 100403
#
#
# 100404
#
#
# 100405
#
#
# 100406
#
#
# 100407
#
#
# 100408
#
#
# 100409
#
#
# 100410
#
#
# 100411
#
#
# 100412
#
#
# 100413
#
#
# 100414
#
#
# 100415
#
#
# 100416
#
#
# 100417
#
#
# 100418
#
#
# 100419
#
#
# 100420
#
#
# 100421
#
#
# 100422
#
#
# 100423
#
#
# 100424
#
#
# 100425
#
#
# 100426
#
#
# 100427
#
#
# 100428
#
#
# 100429
#
#
# 100430
#
#
# 100431
#
#
# 100432
#
#
# 100433
#
#
# 100434
#
#
# 100435
#
#
# 100436
#
#
# 100437
#
#
# 100438
#
#
# 100439
#
#
# 100440
#
#
# 100441
#
#
# 100442
#
#
# 100443
#
#
# 100444
#
#
# 100445
#
#
# 100446
#
#
# 100447
#
#
# 100448
#
#
# 100449
#
#
# 100450
#
#
# 100451
#
#
# 100452
#
#
# 100453
#
#
# 100454
#
#
# 100455
#
#
# 100456
#
#
# 100457
#
#
# 100458
#
#
# 100459
#
#
# 100460
#
#
# 100461
#
#
# 100462
#
#
# 100463
#
#
# 100464
#
#
# 100465
#
#
# 100466
#
#
# 100467
#
#
# 100468
#
#
# 100469
#
#
# 100470
#
#
# 100471
#
#
# 100472
#
#
# 100473
#
#
# 100474
#
#
# 100475
#
#
# 100476
#
#
# 100477
#
#
# 100478
#
#
# 100479
#
#
# 100480
#
#
# 100481
#
#
# 100482
#
#
# 100483
#
#
# 100484
#
#
# 100485
#
#
# 100486
#
#
# 100487
#
#
# 100488
#
#
# 100489
#
#
# 100490
#
#
# 100491
#
#
# 100492
#
#
# 100493
#
#
# 100494
#
#
# 100495
#
#
# 100496
#
#
# 100497
#
#
# 100498
#
#
# 100499
#
#
# 100500
#
#
# 100501
#
#
# 100502
#
#
# 100503
#
#
# 100504
#
#
# 100505
#
#
# 100506
#
#
# 100507
#
#
# 100508
#
#
# 100509
#
#
# 100510
#
#
# 100511
#
#
# 100512
#
#
# 100513
#
#
# 100514
#
#
# 100515
#
#
# 100516
#
#
# 100517
#
#
# 100518
#
#
# 100519
#
#
# 100520
#
#
# 100521
#
#
# 100522
#
#
# 100523
#
#
# 100524
#
#
# 100525
#
#
# 100526
#
#
# 100527
#
#
# 100528
#
#
# 100529
#
#
# 100530
#
#
# 100531
#
#
# 100532
#
#
# 100533
#
#
# 100534
#
#
# 100535
#
#
# 100536
#
#
# 100537
#
#
# 100538
#
#
# 100539
#
#
# 100540
#
#
# 100541
#
#
# 100542
#
#
# 100543
#
#
# 100544
#
#
# 100545
#
#
# 100546
#
#
# 100547
#
#
# 100548
#
#
# 100549
#
#
# 100550
#
#
# 100551
#
#
# 100552
#
#
# 100553
#
#
# 100554
#
#
# 100555
#
#
# 100556
#
#
# 100557
#
#
# 100558
#
#
# 100559
#
#
# 100560
#
#
# 100561
#
#
# 100562
#
#
# 100563
#
#
# 100564
#
#
# 100565
#
#
# 100566
#
#
# 100567
#
#
# 100568
#
#
# 100569
#
#
# 100570
#
#
# 100571
#
#
# 100572
#
#
# 100573
#
#
# 100574
#
#
# 100575
#
#
# 100576
#
#
# 100577
#
#
# 100578
#
#
# 100579
#
#
# 100580
#
#
# 100581
#
#
# 100582
#
#
# 100583
#
#
# 100584
#
#
# 100585
#
#
# 100586
#
#
# 100587
#
#
# 100588
#
#
# 100589
#
#
# 100590
#
#
# 100591
#
#
# 100592
#
#
# 100593
#
#
# 100594
#
#
# 100595
#
#
# 100596
#
#
# 100597
#
#
# 100598
#
#
# 100599
#
#
# 100600
#
#
# 100601
#
#
# 100602
#
#
# 100603
#
#
# 100604
#
#
# 100605
#
#
# 100606
#
#
# 100607
#
#
# 100608
#
#
# 100609
#
#
# 100610
#
#
# 100611
#
#
# 100612
#
#
# 100613
#
#
# 100614
#
#
# 100615
#
#
# 100616
#
#
# 100617
#
#
# 100618
#
#
# 100619
#
#
# 100620
#
#
# 100621
#
#
# 100622
#
#
# 100623
#
#
# 100624
#
#
# 100625
#
#
# 100626
#
#
# 100627
#
#
# 100628
#
#
# 100629
#
#
# 100630
#
#
# 100631
#
#
# 100632
#
#
# 100633
#
#
# 100634
#
#
# 100635
#
#
# 100636
#
#
# 100637
#
#
# 100638
#
#
# 100639
#
#
# 100640
#
#
# 100641
#
#
# 100642
#
#
# 100643
#
#
# 100644
#
#
# 100645
#
#
# 100646
#
#
# 100647
#
#
# 100648
#
#
# 100649
#
#
# 100650
#
#
# 100651
#
#
# 100652
#
#
# 100653
#
#
# 100654
#
#
# 100655
#
#
# 100656
#
#
# 100657
#
#
# 100658
#
#
# 100659
#
#
# 100660
#
#
# 100661
#
#
# 100662
#
#
# 100663
#
#
# 100664
#
#
# 100665
#
#
# 100666
#
#
# 100667
#
#
# 100668
#
#
# 100669
#
#
# 100670
#
#
# 100671
#
#
# 100672
#
#
# 100673
#
#
# 100674
#
#
# 100675
#
#
# 100676
#
#
# 100677
#
#
# 100678
#
#
# 100679
#
#
# 100680
#
#
# 100681
#
#
# 100682
#
#
# 100683
#
#
# 100684
#
#
# 100685
#
#
# 100686
#
#
# 100687
#
#
# 100688
#
#
# 100689
#
#
# 100690
#
#
# 100691
#
#
# 100692
#
#
# 100693
#
#
# 100694
#
#
# 100695
#
#
# 100696
#
#
# 100697
#
#
# 100698
#
#
# 100699
#
#
# 100700
#
#
# 100701
#
#
# 100702
#
#
# 100703
#
#
# 100704
#
#
# 100705
#
#
# 100706
#
#
# 100707
#
#
# 100708
#
#
# 100709
#
#
# 100710
#
#
# 100711
#
#
# 100712
#
#
# 100713
#
#
# 100714
#
#
# 100715
#
#
# 100716
#
#
# 100717
#
#
# 100718
#
#
# 100719
#
#
# 100720
#
#
# 100721
#
#
# 100722
#
#
# 100723
#
#
# 100724
#
#
# 100725
#
#
# 100726
#
#
# 100727
#
#
# 100728
#
#
# 100729
#
#
# 100730
#
#
# 100731
#
#
# 100732
#
#
# 100733
#
#
# 100734
#
#
# 100735
#
#
# 100736
#
#
# 100737
#
#
# 100738
#
#
# 100739
#
#
# 100740
#
#
# 100741
#
#
# 100742
#
#
# 100743
#
#
# 100744
#
#
# 100745
#
#
# 100746
#
#
# 100747
#
#
# 100748
#
#
# 100749
#
#
# 100750
#
#
# 100751
#
#
# 100752
#
#
# 100753
#
#
# 100754
#
#
# 100755
#
#
# 100756
#
#
# 100757
#
#
# 100758
#
#
# 100759
#
#
# 100760
#
#
# 100761
#
#
# 100762
#
#
# 100763
#
#
# 100764
#
#
# 100765
#
#
# 100766
#
#
# 100767
#
#
# 100768
#
#
# 100769
#
#
# 100770
#
#
# 100771
#
#
# 100772
#
#
# 100773
#
#
# 100774
#
#
# 100775
#
#
# 100776
#
#
# 100777
#
#
# 100778
#
#
# 100779
#
#
# 100780
#
#
# 100781
#
#
# 100782
#
#
# 100783
#
#
# 100784
#
#
# 100785
#
#
# 100786
#
#
# 100787
#
#
# 100788
#
#
# 100789
#
#
# 100790
#
#
# 100791
#
#
# 100792
#
#
# 100793
#
#
# 100794
#
#
# 100795
#
#
# 100796
#
#
# 100797
#
#
# 100798
#
#
# 100799
#
#
# 100800
#
#
# 100801
#
#
# 100802
#
#
# 100803
#
#
# 100804
#
#
# 100805
#
#
# 100806
#
#
# 100807
#
#
# 100808
#
#
# 100809
#
#
# 100810
#
#
# 100811
#
#
# 100812
#
#
# 100813
#
#
# 100814
#
#
# 100815
#
#
# 100816
#
#
# 100817
#
#
# 100818
#
#
# 100819
#
#
# 100820
#
#
# 100821
#
#
# 100822
#
#
# 100823
#
#
# 100824
#
#
# 100825
#
#
# 100826
#
#
# 100827
#
#
# 100828
#
#
# 100829
#
#
# 100830
#
#
# 100831
#
#
# 100832
#
#
# 100833
#
#
# 100834
#
#
# 100835
#
#
# 100836
#
#
# 100837
#
#
# 100838
#
#
# 100839
#
#
# 100840
#
#
# 100841
#
#
# 100842
#
#
# 100843
#
#
# 100844
#
#
# 100845
#
#
# 100846
#
#
# 100847
#
#
# 100848
#
#
# 100849
#
#
# 100850
#
#
# 100851
#
#
# 100852
#
#
# 100853
#
#
# 100854
#
#
# 100855
#
#
# 100856
#
#
# 100857
#
#
# 100858
#
#
# 100859
#
#
# 100860
#
#
# 100861
#
#
# 100862
#
#
# 100863
#
#
# 100864
#
#
# 100865
#
#
# 100866
#
#
# 100867
#
#
# 100868
#
#
# 100869
#
#
# 100870
#
#
# 100871
#
#
# 100872
#
#
# 100873
#
#
# 100874
#
#
# 100875
#
#
# 100876
#
#
# 100877
#
#
# 100878
#
#
# 100879
#
#
# 100880
#
#
# 100881
#
#
# 100882
#
#
# 100883
#
#
# 100884
#
#
# 100885
#
#
# 100886
#
#
# 100887
#
#
# 100888
#
#
# 100889
#
#
# 100890
#
#
# 100891
#
#
# 100892
#
#
# 100893
#
#
# 100894
#
#
# 100895
#
#
# 100896
#
#
# 100897
#
#
# 100898
#
#
# 100899
#
#
# 100900
#
#
# 100901
#
#
# 100902
#
#
# 100903
#
#
# 100904
#
#
# 100905
#
#
# 100906
#
#
# 100907
#
#
# 100908
#
#
# 100909
#
#
# 100910
#
#
# 100911
#
#
# 100912
#
#
# 100913
#
#
# 100914
#
#
# 100915
#
#
# 100916
#
#
# 100917
#
#
# 100918
#
#
# 100919
#
#
# 100920
#
#
# 100921
#
#
# 100922
#
#
# 100923
#
#
# 100924
#
#
# 100925
#
#
# 100926
#
#
# 100927
#
#
# 100928
#
#
# 100929
#
#
# 100930
#
#
# 100931
#
#
# 100932
#
#
# 100933
#
#
# 100934
#
#
# 100935
#
#
# 100936
#
#
# 100937
#
#
# 100938
#
#
# 100939
#
#
# 100940
#
#
# 100941
#
#
# 100942
#
#
# 100943
#
#
# 100944
#
#
# 100945
#
#
# 100946
#
#
# 100947
#
#
# 100948
#
#
# 100949
#
#
# 100950
#
#
# 100951
#
#
# 100952
#
#
# 100953
#
#
# 100954
#
#
# 100955
#
#
# 100956
#
#
# 100957
#
#
# 100958
#
#
# 100959
#
#
# 100960
#
#
# 100961
#
#
# 100962
#
#
# 100963
#
#
# 100964
#
#
# 100965
#
#
# 100966
#
#
# 100967
#
#
# 100968
#
#
# 100969
#
#
# 100970
#
#
# 100971
#
#
# 100972
#
#
# 100973
#
#
# 100974
#
#
# 100975
#
#
# 100976
#
#
# 100977
#
#
# 100978
#
#
# 100979
#
#
# 100980
#
#
# 100981
#
#
# 100982
#
#
# 100983
#
#
# 100984
#
#
# 100985
#
#
# 100986
#
#
# 100987
#
#
# 100988
#
#
# 100989
#
#
# 100990
#
#
# 100991
#
#
# 100992
#
#
# 100993
#
#
# 100994
#
#
# 100995
#
#
# 100996
#
#
# 100997
#
#
# 100998
#
#
# 100999

# %%
getting_tle(82458)
# Out:
# 1 82458U          25159.68816151 +.00002730 +00000+0 +12733-2 0  9994
# 2 82458  66.5151 310.0397 0047040 146.6678 213.7392 14.21353264583441

# %%
text= open("C:\\Users\\Joel\\Documents\\Python\\email\\tle_filt.txt", "r")
f=text.readlines()
text.close()
text="".join(f)

# %%
import re
aux=re.findall(r"(1[\s\S]{68})\n{2}(2[\s\S]{68})",text)

# %%
print(aux[0][0])
# Out:
# 1    11U 59001A   25161.83603414  .00001228  00000-0  65005-3 0  9993

# %%
textfile= open("C:\\Users\\Joel\\Documents\\Python\\email\\TLE_bueno.txt", "a")
for i in aux:
    textfile.write(i[0]+"\n")
    textfile.write(i[1]+"\n\n")
textfile.close()

# %%
len(f)/2
# Out:
# 27777.5

# %%
len(aux)
# Out:
# 27777

# %%
import requests
from bs4 import BeautifulSoup as bs


def getting_tle(i):
    page = requests.get('https://www.n2yo.com/satellite/?s='+str(i)+'#results')
    soup = bs(page.text, 'html.parser')
    pre_tags = soup.find("pre")
    print(pre_tags)



getting_tle(2)
# Out:
# <pre>
#
#
# </pre>

# %% [markdown]
# ## Case with data

# %%
import re

pre_tags= """<pre>
1 39035U 12075B   25160.87366212 -.00000005  00000-0  00000-0 0  9990
2 39035   0.0460 111.6047 0002220 328.0059  18.5926  1.00272508 45741
</pre>"""

#print(pre_tags)


print(pre_tags[6:-7])
#tle= re.compile(r"<pre>\n\d\s[A-Za-z0-9]+\s[A-Za-z0-9]+")#<pre> \d\s[A-Za-z0-9]+\s[A-Za-z0-9]+
#print(tle.match(pre_tags))
# Out:
# 1 39035U 12075B   25160.87366212 -.00000005  00000-0  00000-0 0  9990
# 2 39035   0.0460 111.6047 0002220 328.0059  18.5926  1.00272508 45741

# %% [markdown]
# # Case without data

# %%
import re

pre_tags= """<pre>


</pre>"""

print(pre_tags)

print(pre_tags[5:-6])
# Out:
# <pre>
#
#
# </pre>

# %%
import re
import requests
from bs4 import BeautifulSoup as bs


def getting_tle(i):
    page = requests.get('https://www.n2yo.com/satellite/?s='+str(i)+'#results')
    soup = bs(page.text, 'html.parser')
    pre_tags = soup.find("pre")
    #print(pre_tags)
    str_pre_tags= str(pre_tags)
    #print(str_pre_tags)
    if len(str_pre_tags[7:-7]) > 15:
        #print("APPENDEAMOS")
        print(str_pre_tags[7:-7])
    else:
        print("No apendeamos nada")


getting_tle(39036)
# Out:
# 1 39036U 12075C   25169.40845272  .00000988  00000-0  54994-3 0  9990
# 2 39036   2.7061  37.7910 7124957 184.6172 160.5293  2.46304228107746

# %%
#tle= re.compile(r"\<pre\>[\n\r](1[\s\w]{68})[\n\r](2[\s\w]{68})[\n\r]\</pre\>")#<pre> \d\s[A-Za-z0-9]+\s[A-Za-z0-9]+
#print(tle.match(pre_tags))

# %%
test_var='''1 82458U          25159.68816151 +.00002730 +00000+0 +12733-2 0  9994
2 82458  66.5151 310.0397 0047040 146.6678 213.7392 14.21353264583441'''

print(test_var)

SatNum= test_var[2:7]
SatNumClass= test_var[7]
IntDes_LaunchYear= test_var[9:11]
IntDes_LaunchNumYear= test_var[11:14]
IntDes_PieceLaunch= test_var[14:17]
EpochYear= test_var[18:20]
Epoch_DayYear= test_var[20:32]
FirstTimeDerivateMeanMotion= test_var[33:43]
SecondTimeDerivateMeanMotion= test_var[44:52]
BSTAR= test_var[53:61]
EphemerisType= test_var[62]
ElementNumber= test_var[64:68]
Checksum= test_var[68]

SatNum_L2= test_var[72:77]
Inclination_L2= test_var[78:86]
RightAscension_L2= test_var[87:95]
Eccentricity_L2= test_var[96:103]
ArgumentPerigee_L2= test_var[104:112]
MeanAnomaly_L2= test_var[113:121]
MeanMotion_L2= test_var[122:133]
RevNumEpoch_L2= test_var[133:138]
Checksum_L2= test_var[138]


print(SatNum)
print(SatNumClass)
print(IntDes_LaunchYear)
print(IntDes_LaunchNumYear)
print(IntDes_PieceLaunch)
print(EpochYear)
print(Epoch_DayYear)
print(FirstTimeDerivateMeanMotion)
print(SecondTimeDerivateMeanMotion)
print(BSTAR)
print(EphemerisType)
print(ElementNumber)
print(Checksum)

print(SatNum_L2)
print(Inclination_L2)
print(RightAscension_L2)
print(Eccentricity_L2)
print(ArgumentPerigee_L2)
print(MeanAnomaly_L2)
print(MeanMotion_L2)
print(RevNumEpoch_L2)
print(Checksum_L2)
# Out:
# 1 82458U          25159.68816151 +.00002730 +00000+0 +12733-2 0  9994
# 2 82458  66.5151 310.0397 0047040 146.6678 213.7392 14.21353264583441
# 82458
# U
#
#
#
# 25
# 159.68816151
# +.00002730
# +00000+0
# +12733-2
# 0
#  999
# 4
# 82458
#  66.5151
# 310.0397
# 0047040
# 146.6678
# 213.7392
# 14.21353264
# 58344
# 1

# %% [markdown]
# # COMENTAR LOS PRINTS

# %%
import requests
from bs4 import BeautifulSoup as bs
from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

def getting_tle(i):
    page = requests.get('https://www.n2yo.com/satellite/?s='+str(i)+'#results')
    soup = bs(page.text, 'html.parser')
    pre_tags = soup.find("pre")
    str_pre_tags= str(pre_tags)[7:-7]
    #print(str_pre_tags)

    if len(str_pre_tags) > 1:
        SatNum= str_pre_tags[2:7]
        SatNumClass= str_pre_tags[7]
        IntDes_LaunchYear= str_pre_tags[9:11]
        IntDes_LaunchNumYear= str_pre_tags[11:14]
        IntDes_PieceLaunch= str_pre_tags[14:17]
        EpochYear= str_pre_tags[18:20]
        Epoch_DayYear= str_pre_tags[20:32]
        FirstTimeDerivateMeanMotion= str_pre_tags[33:43]
        SecondTimeDerivateMeanMotion= str_pre_tags[44:52]
        BSTAR= str_pre_tags[53:61]
        EphemerisType= str_pre_tags[62]
        ElementNumber= str_pre_tags[64:68]
        Checksum= str_pre_tags[68]

        SatNum_L2= str_pre_tags[73:78]
        Inclination_L2= str_pre_tags[79:87]
        RightAscension_L2= str_pre_tags[87:96]
        Eccentricity_L2= str_pre_tags[96:104]
        ArgumentPerigee_L2= str_pre_tags[104:113]
        MeanAnomaly_L2= str_pre_tags[113:122]
        MeanMotion_L2= str_pre_tags[122:134]
        RevNumEpoch_L2= str_pre_tags[134:139]
        Checksum_L2= str_pre_tags[139]

        #print(SatNum)
        #print(SatNumClass)
        #print(IntDes_LaunchYear)
        #print(IntDes_LaunchNumYear)
        #print(IntDes_PieceLaunch)
        #print(EpochYear)
        #print(Epoch_DayYear)
        #print(FirstTimeDerivateMeanMotion)
        #print(SecondTimeDerivateMeanMotion)
        #print(BSTAR)
        #print(EphemerisType)
        #print(ElementNumber)
        #print(Checksum)

        #print(SatNum_L2)
        #print(Inclination_L2)
        #print(RightAscension_L2)
        #print(Eccentricity_L2)
        #print(ArgumentPerigee_L2)
        #print(MeanAnomaly_L2)
        print(MeanMotion_L2)
        #print(RevNumEpoch_L2)
        #print(Checksum_L2)

        Eccentricity_L2=Eccentricity_L2.strip()
        #print(Eccentricity_L2)
        Eccentricity_L2="."+Eccentricity_L2
        #print(Eccentricity_L2)
        print(float(Eccentricity_L2))

        if float(MeanMotion_L2) < 2 and float(Eccentricity_L2) > 0.5:
            #print(MeanMotion_L2)
            textfile= open("C:\\Users\\Joel\\Documents\\Python\\email\\MeanMotion_Eccentricity.txt", "a")
            textfile.write(str_pre_tags+"\n\n\n")
            textfile.close()

# %%
for i in range (1, 100000):
    print(i)
    getting_tle(i)

# %%
getting_tle(553)
# Out:
#   1.16484294
# 0.0791992

# %%
my_string = "   Hello World   "
trimmed = my_string.strip()  
# trimmed = "Hello World"
print(trimmed)
# Out:
# Hello World

# %% [markdown]
# # Web Scrapping of Apogee and Perigee

# %%
import requests
from bs4 import BeautifulSoup as bs

page = requests.get('https://www.n2yo.com/satellite/?s=39035#results') #39035
#print(page)
#print(page.content)
soup = bs(page.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <head>
# <title>MEXSAT 3 Satellite details 2012-075B NORAD 39035</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link href="/css/style.css" rel="stylesheet" type="text/css"/>
# <script src="/js/jquery-1.11.js"></script>
# <script src="/js/timezone.js?1750806588" type="text/javascript"></script>
# <script src="/js/tooltip.js" type="text/javascript"></script>
# <script src="/js/tooltip-items.js" type="text/javascript"></script>
# <meta content="https://www.n2yo.com//satellite/?s=39035" property="og:url">
# <meta content="Technical details for satellite MEXSAT 3" property="og:title"/>
# <meta content="https://www.n2yo.com/img/n2yo-circle-fb.png" property="og:image"/>
# <meta content="N2YO.com - Real Time Satellite Tracking and Predictions" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Mexsat Bicentenario, also named Mexsat 3, will provide fixed communications services with 12 active C-band and 12 active Ku-band transponders. From its operating post at 114...." property="og:description"/>
# <meta content="MEXSAT 3, 2012-075B, 39035, satellite tracking, passes, prediction, satellite database" name="keywords"/>
# <meta content="Technical details about the MEXSAT 3 (2012-075B or NORAD 39035) satellite. MEXSAT 3 can be selected for live tracking or to see the passes visible from your location, if applicable" name="description"/>
# </meta></head>
# <body>
# <script src="/js/passes.js" type="text/javascript"></script>
# <script>
# var startPass = null;
# var endPass = null;
# var timer;
# var issid = 25544;
# var lat = 37.54827;
# var lng = -121.98857;
# go();
# </script>
# <!--
# <script type='text/javascript'>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script> -->
# <!-- Google tag Analytics (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-QZGWPSKPV5"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-QZGWPSKPV5');
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/31043081/n2yo-header', [728, 90], 'div-gpt-ad-1438712706402-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <div id="headercontainer" style="overflow: auto; zoom: 1">
# <table style="width:100%;font-size:14px">
# <tr>
# <td>
# <div id="logo">
# <a href="/"><img alt="n2yo.com" border="0" height="39" src="/img/n2yologo.png" width="200"/></a>
# <div class="fb-like" data-font="tahoma" data-href="https://www.facebook.com/n2yodotcom" data-layout="button_count" data-send="false" data-show-faces="false" data-width="100"></div>
# <g:plusone></g:plusone>
# </div>
# <span id="headermessage" style="background-color:#ffffca;border:1px dashed #cacaba;width:300px;">
#
# 	Tracking <b><span style="color:#d50000">30743</span></b> objects as of 24-Jun-2025	<br/><a href="/space-station/">
# 	HD Live streaming from Space Station</a>
# <br/>
# <script src="/js/satellite-js/dist/satellite.min.js"></script>
# <link href="/css/odometer-theme-car.css" rel="stylesheet">
# <script src="/js/odometer.js"></script>
# <style>
# .odometer {
#     font-size: 16px;
# }
# </style>
# <span id="up"><div class="odometer" id="odometer"></div> objects crossing your sky now
# <script>
# var items;
# if (!( /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) )) {
#
# 	$.get("/inc/all.php", function(data) {
# 		  items = data.split('\n');
# 		up();
# 	});
# 	setInterval('up()', 5000);
# }
# else
# {
#     document.getElementById("up").style.display='none';
# }
# function up()
# {
# 	  var cnt = 0;
# 	  for(var i=0;i<items.length;i++)
# 	  {
# 		var line = items[i];
# 		if(line[0]=="1")
# 		  {
# 			var satid = parseInt(line.substr(2,5));
# 			var line1 = items[i];
# 			var line2 = items[i+1];
# 			var satrec = satellite.twoline2satrec(line1, line2);
# 			var now = new Date();
#
#
# 			var positionAndVelocity = satellite.propagate(
# 				satrec,
# 				now.getUTCFullYear(),
# 				now.getUTCMonth() + 1,
# 				now.getUTCDate(),
# 				now.getUTCHours(),
# 				now.getUTCMinutes(),
# 				now.getUTCSeconds()
# 			);
#
#
#
# 			var positionEci = positionAndVelocity.position,
# 		    velocityEci = positionAndVelocity.velocity;
#
# 			var gmst = satellite.gstimeFromDate(
# 		    now.getUTCFullYear(),
# 		    now.getUTCMonth() + 1,
# 		    now.getUTCDate(),
# 		    now.getUTCHours(),
# 		    now.getUTCMinutes(),
# 		    now.getUTCSeconds()
# 			);
#
# var deg2rad = Math.PI/180;
# var observerGd = {
#     longitude: -121.98857 * deg2rad,
#     latitude: 37.54827 * deg2rad,
#     height: 0
# };
#
# try
# {
#
# 			var positionEcf   = satellite.eciToEcf(positionEci, gmst);
#
# }
# catch (err)
# {
# 												//console.log("Error: " + err);
# }
#
#
#
# 			var lookAngles    = satellite.ecfToLookAngles(observerGd, positionEcf);
#
#
# 		    var dopplerFactor = 0;
# var azimuth   = lookAngles.azimuth,
#     elevation = lookAngles.elevation,
#     rangeSat  = lookAngles.rangeSat;
#
# 			azimuth1 =  azimuth*180/Math.PI;
# 			elevation1 =  elevation*180/Math.PI;
#
#
# 			if(elevation1>10)
# 			  {
# 				cnt++;
# 			  }
#
# 		  }
# 	  }
# 	odometer.innerHTML = cnt;
#
# }
# </script>
# </span>
# </link></span></td>
# <td align="center" valign="top" width="200">
# <!--<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>-->
# <!-- n2yo-com-234x60 -->
# <!--<ins class="adsbygoogle"
#      style="display:inline-block;width:234px;height:60px"
#      data-ad-client="ca-pub-8839140430005838"
#      data-ad-slot="1743584802"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>-->
# <b><span id="countdown" style="display:block"></span></b>
# </td>
# <td align="right" valign="top">
# <form action="/database/#results" method="GET">
# <div align="right" id="searchbox">
# <br/>
# <input id="srcsat" name="q" onfocus='document.getElementById("srcsat").value="";' size="12" style="font-size: 14px; background-color: #FFFFFF;width:140px" type="text" value="Find a satellite..."/>
# <input style="font-size: 12px; background-color:#D8D8D8; color:#000000; margin-right: 6px;" type="submit" value="Search"/>
# <div align="right">
# <a href="https://www.facebook.com/n2yodotcom">N2YO.com on Facebook</a>
#
# 		<a href="/database/">Advanced</a>   </div>
# </div></form>
# </td></tr></table></div>
# <script src="https://apis.google.com/js/plusone.js" type="text/javascript"></script>
#
#
#
#
# <div id="admobiheader">
# <!--
# <script id="mNCC" language="javascript">
#     medianet_width = "468";
#     medianet_height = "60";
#     medianet_crid = "344318977";
#     medianet_versionId = "111299";
#     (function() {
#         var isSSL = 'https:' == document.location.protocol;
#         var mnSrc = (isSSL ? 'https:' : 'http:') + '//contextual.media.net/nmedianet.js?cid=8CUY6IMG3' + (isSSL ? '&https=1' : '');
#         document.write('<scr' + 'ipt type="text/javascript" id="mNSC" src="' + mnSrc + '"></scr' + 'ipt>');
#     })();
#   </script>
# -->
# </div>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3&appId=372896566168367";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <!--
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-8839140430005838",
#           enable_page_level_ads: true
#      });
# </script>
# -->
# <!-- <div style="height:24px;background-color:#ff0000;color:#fff;">
# <center><strong><a href="https://www.n2yo.com/?s=49220" style="color:#fff;visited:#fff;active:#fff;hover:#eee">Track INSPIRATION-4</a></strong></center> -->
#
# <div id="menu">
# <link href="/ddmenu/ddmenu.css" rel="stylesheet" type="text/css"/>
# <script src="/ddmenu/ddmenu.js" type="text/javascript"></script>
# <!--INFOLINKS_OFF-->
# <nav id="ddmenu">
# <div class="menu-icon"></div>
# <ul>
# <li class="no-sub"><a class="top-heading" href="https://www.n2yo.com/">Home</a></li>
# <li>
# <span class="top-heading"><a class="top-heading" href="/satellites/?c=most-popular">Most tracked</a></span>
# <i class="caret"></i>
# <div class="dropdown">
# <div class="dd-inner">
# <div class="column">
# <a href="/satellite/?s=25544">SPACE STATION</a>
# <a href="/satellite/?s=36516">SES 1</a>
# <a href="/satellite/?s=33591">NOAA 19</a>
# <a href="/satellite/?s=29155">GOES 13</a>
# <a href="/satellite/?s=25338">NOAA 15</a>
# <a href="/satellite/?s=28654">NOAA 18</a>
# <a href="/satellite/?s=25994">TERRA</a>
# <a href="/satellite/?s=27424">AQUA</a>
# <a href="/satellite/?s=38771">METOP-B</a>
# <a href="/satellite/?s=37849">SUOMI NPP</a>
# <a href="/satellite/?s=36411">GOES 15</a>
# <a href="/satellite/?s=40967">FOX-1A (AO-85)</a>
# <a href="/satellite/?s=27607">SAUDISAT 1C</a>
# <a href="/satellite/?s=41332">KMS-4</a>
# <a href="/satellite/?s=37820">TIANGONG 1</a>
# <a href="/satellite/?s=40069">METEOR M2</a>
# <a href="/satellite/?s=25657">ASIASAT 3S</a>
# <a href="/satellite/?s=36032">NSS 12</a>
# <a href="/satellite/?s=31135">AGILE</a>
# <a href="/satellite/?s=40147">MEASAT 3B</a>
# <a href="/satellites/?c=most-popular">MORE...</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <span class="top-heading"><a class="top-heading" href="/satellites/?c=latest-launches">Just launched</a></span>
# <i class="caret"></i>
# <div class="dropdown">
# <div class="dd-inner">
# <div class="column">
# <a href="/satellite/?s=64470">CHINASAT-9C</a>
# <a href="/satellite/?s=64467">COSMOS 2589</a>
# <a href="/satellite/?s=64466">USA 547</a>
# <a href="/satellite/?s=64340">QPS-SAR-11</a>
# <a href="/satellite/?s=64339">STARLINK-34017</a>
# <a href="/satellite/?s=64338">STARLINK-34218</a>
# <a href="/satellite/?s=64337">STARLINK-34216</a>
# <a href="/satellite/?s=64336">STARLINK-34223</a>
# <a href="/satellite/?s=64335">STARLINK-33855</a>
# <a href="/satellite/?s=64334">STARLINK-34260</a>
# <a href="/satellite/?s=64333">STARLINK-34207</a>
# <a href="/satellite/?s=64332">STARLINK-33782</a>
# <a href="/satellite/?s=64331">STARLINK-34050</a>
# <a href="/satellite/?s=64330">STARLINK-34252</a>
# <a href="/satellite/?s=64329">STARLINK-11734</a>
# <a href="/satellite/?s=64328">STARLINK-11707</a>
# <a href="/satellite/?s=64327">STARLINK-11674</a>
# <a href="/satellite/?s=64326">STARLINK-11678</a>
# <a href="/satellite/?s=64325">STARLINK-11698</a>
# <a href="/satellite/?s=64324">STARLINK-11696</a>
# <a href="/satellites/?c=latest-launches">MORE...</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <span class="top-heading">Satellites on orbit</span>
# <i class="caret"></i>
# <div class="dropdown">
# <div class="dd-inner">
# <div class="column">
# <h4><a href="/satellites/">CATEGORIES</a></h4>
# <a href="/satellites/?c=2">Int'l Space Station</a>
# <a href="/satellites/?c=54">Chinese Space Station</a>
# <a href="/satellites/?c=1">Brightest</a>
# <a href="/satellites/?c=52">Starlink</a>
# <a href="/satellites/?c=20">GPS Operational</a>
# <a href="/satellites/?c=21">Glonass Operational</a>
# <a href="/satellites/?c=22">Galileo</a>
# <a href="/satellites/?c=35">Beidou</a>
# <a href="/satellites/?c=30">Military</a>
# <a href="/satellites/?c=15">Iridium</a>
# <a href="/satellites/?c=17">Globalstar</a>
# <a href="/satellites/?c=10">Geostationary</a>
# <a href="/satellites/?c=26">Space &amp; Earth Science</a>
# <a href="/satellites/?c=3">Weather</a>
# <a href="/satellites/?c=18">Amateur radio</a>
# <a href="/satellites/">MORE CATEGORIES...</a>
# </div>
# <div class="column">
# <h4><a href="/whats-up/whats-up-now.php">WHAT'S UP?</a></h4>
# <a href="/passes/amateur-radio.php">Amateur radio sat passes</a>
# <a href="/whats-up/?c=20">GPS satellites</a>
# <a href="/whats-up/?c=21">Glonass satellites</a>
# <a href="/whats-up/?c=35">Beidou satellites</a>
# <a href="/whats-up/?c=22">Galileo satellites</a>
# <a href="/whats-up/?c=15">Iridium satellites</a>
# <a href="/whats-up/?c=17">Globalstar satellites</a>
# <!--<a href="/whats-up/whats-up-now.php" style="color:red">What's up in your sky now?</a>-->
# <br/>
# <h4><a href="/database/">FIND A SATELLITE</a></h4>
# <a href="/database/"> SEARCH DATABASE</a>
# <a href="/browse/"> BROWSE BY LAUNCH DATE</a>
# <a href="/satellites/"> BROWSE BY CATEGORY</a>
# <a href="/satellites/?c=&amp;t=country"> BROWSE BY COUNTRY</a>
# </div>
# <div class="column">
# <h4><a href="/satellites?c=&amp;t=country">OWNERS/COUNTRIES</a></h4>
# <a href="/satellites?c=US&amp;t=country"><img border="0" height="15" src="/img/org/us.gif" style="vertical-align: text-bottom" width="20"/> UNITED STATES</a>
# <a href="/satellites?c=CIS&amp;t=country"><img border="0" height="15" src="/img/org/cis.gif" style="vertical-align: text-bottom" width="20"/> CIS (FORMER USSR)</a>
# <a href="/satellites?c=PRC&amp;t=country"><img border="0" height="15" src="/img/org/prc.gif" style="vertical-align: text-bottom" width="20"/> PEOPLE'S REPUBLIC OF CHINA</a>
# <a href="/satellites?c=JPN&amp;t=country"><img border="0" height="15" src="/img/org/jpn.gif" style="vertical-align: text-bottom" width="20"/> JAPAN</a>
# <a href="/satellites?c=ESA&amp;t=country"><img border="0" height="15" src="/img/org/esa.gif" style="vertical-align: text-bottom" width="20"/> EUROPEAN SPACE AGENCY</a>
# <a href="/satellites?c=FR&amp;t=country"><img border="0" height="15" src="/img/org/fr.gif" style="vertical-align: text-bottom" width="20"/> FRANCE</a>
# <a href="/satellites?c=IND&amp;t=country"><img border="0" height="15" src="/img/org/ind.gif" style="vertical-align: text-bottom" width="20"/> INDIA</a>
# <a href="/satellites?c=UK&amp;t=country"><img border="0" height="15" src="/img/org/uk.gif" style="vertical-align: text-bottom" width="20"/> UNITED KINGDOM</a>
# <a href="/satellites?c=CA&amp;t=country"><img border="0" height="15" src="/img/org/ca.gif" style="vertical-align: text-bottom" width="20"/> CANADA</a>
# <a href="/satellites?c=GER&amp;t=country"><img border="0" height="15" src="/img/org/ger.gif" style="vertical-align: text-bottom" width="20"/> GERMANY</a>
# <a href="/satellites?c=&amp;t=country"> MORE OWNERS/COUNTRIES...</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="top-heading" href="/info/?a=22">Alerting tools</a>
# <i class="caret"></i>
# <div class="dropdown right-aligned">
# <div class="dd-inner">
# <div class="column">
# <h4>ALERTING TOOLS</h4>
# <a href="/info/?a=43"><img border="0" src="/ddmenu/phone.png" style="vertical-align: text-bottom" width="16"/> SPACE STATION PREDICTIONS BY VOICE</a>
# <a href="/login/iss-notifications/"><img border="0" src="/ddmenu/alert.png" style="vertical-align: text-bottom" width="16"/> SPACE STATION NOTIFICATION TOOL </a>
# <a href="/info/?a=15"><img border="0" src="/ddmenu/email.png" style="vertical-align: text-bottom" width="16"/> ALERTS BY EMAIL AND SMS</a>
# </div>
# </div>
# </div></li>
# <li>
# <span class="top-heading">More stuff</span>
# <i class="caret"></i>
# <div class="dropdown right-aligned">
# <div class="dd-inner">
# <div class="column">
# <h4>ADDITIONAL INFO</h4>
# <a href="/space-station" style="color:red"><b>HD LIVE STREAMING FROM ISS</b></a>
# <a href="/news/read.php?p=0">SATELLITE NEWS</a>
# <a href="/about/?a=donation">MAKE A DONATION</a>
# <a href="https://www.facebook.com/n2yodotcom">N2YO.COM ON FACEBOOK</a>
# <a href="/about/?a=links">EXTERNAL LINKS</a>
# <a href="/about/?a=faq">FAQ</a>
# <a href="/about/?a=feedback">CONTACT/FEEDBACK</a>
# <a href="/about/?a=privacy">PRIVACY POLICY</a>
# <a href="/about/?a=terms">TERMS OF USE</a>
# </div>
# <div class="column">
# <h4>USER PREFERENCES</h4>
# <a href="https://www.n2yo.com/login/edit/">SIGN IN</a> <a href="https://www.n2yo.com/login/edit/">EDIT/CHANGE YOUR LOCATION</a>
# <br/>
# <h4>SITE OWNERS</h4>
# <a href="/widgets/">WIDGETS FOR YOUR PAGE</a>
# <a href="/api/">API ACCESS</a>
# <br/>
# <!-- <h4>MOBILE APPS</h4>
#                     <a href="http://southernstars.com/products/"  style="color:red"><strong>Orbitrack</strong> - <b>NEW</b> (iOS and Android)</a> -->
# </div>
# </div>
# </div>
# </li>
# <li class="no-sub"><a class="top-heading" href="https://www.n2yo.com/login/edit/">Sign in</a></li>
# </ul>
# </nav>
# <!--INFOLINKS_ON-->
# </div>
# <table id="tabsatellite" width="100%">
# <tr>
# <td class="hidecell" style="width:160px">
# <script id="mNCC" language="javascript">
#     medianet_width = "160";
#     medianet_height = "600";
#     medianet_crid = "515138167";
#     medianet_versionId = "111299";
#     (function() {
#         var isSSL = 'https:' == document.location.protocol;
#         var mnSrc = (isSSL ? 'https:' : 'http:') + '//contextual.media.net/nmedianet.js?cid=8CUY6IMG3' + (isSSL ? '&https=1' : '');
#         document.write('<scr' + 'ipt type="text/javascript" id="mNSC" src="' + mnSrc + '"></scr' + 'ipt>');
#     })();
#   </script>
# </td>
# <td>
# <div id="satinfo">
# <h1>MEXSAT 3</h1>
# <p class="spaced">
# <a href="/?s=39035&amp;live=1">Track MEXSAT 3 now!</a>
# <br/>MEXSAT 3 is classified as: <ul>
# <li class="arrow"><a href="/satellites/?c=10">Geostationary</a>
# </li></ul>
# </p>
# <br>
# <b>NORAD ID</b>: 39035 <a class="showTip noradid" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Int'l Code</b>: 2012-075B <a class="showTip intlcode" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Perigee</b>: 35,786.8 km <a class="showTip perigee" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Apogee</b>: 35,800.7 km <a class="showTip apogee" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Inclination</b>: 0.0 ° <a class="showTip inclination" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Period</b>: 1,436.1 minutes <a class="showTip period" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Semi major axis</b>: 42164 km <a class="showTip semimajoraxis" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>RCS</b>: 4.6929 m<sup>2</sup> (large) <a class="showTip rcs" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Launch date</b>: <a href="/browse/?y=2012&amp;m=12">December 19, 2012</a>
# <br/><b>Source</b>: Mexico (MEX)
# 			<br/><b>Launch site</b>: FRENCH GUIANA (FRGUI)
#
#
#
#
#
#
#
#
# 									<br/><br/>Mexsat Bicentenario, also named Mexsat 3, will provide fixed communications services with 12 active C-band and 12 active Ku-band transponders. From its operating post at 114.9 degrees west longitude, the satellite's communications payload will reach users across Mexico and surrounding waters. Boeing is building two larger satellites tailored for mobile communications services. The Mexsat system is expected to be in service until 2028. Mexsat Bicentenario is based on Orbital's GEOStar 2 satellite bus. It will enter service in 2013, beaming broadband Internet, telephone, telemedicine, education and videoconferencing across Mexico. It will also reach rural communities not served by existing infrastructure. The Mexsat system will aid Mexican government officials in disaster response and national security applications, according to the Mexican Ministry of Communications and Transportation.
#
# 		</br></div>
# <div id="adsatellitepage">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Responsive bottom -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-8839140430005838" data-ad-format="auto" data-ad-slot="6966096404" style="display:block"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
# <div id="satgraphics">
# <table id="tabtracking">
# <tr>
# <td class="tabheader">
# 		Your satellite tracking list
# 		</td>
# </tr>
# <tr>
# <td>
# <center>
# <form method="POST" name="addsat">
# <input name="satid" type="hidden" value="39035"/>
# <input name="satname" type="hidden" value="MEXSAT 3"/>
# <!--<a href='javascript:document.addsat.submit()'>Add MEXSAT 3 on your tracking list</a>-->
# <input class="sButton" onclick="javascript:document.addsat.submit()" type="button" value="Add MEXSAT 3 on your tracking list">
# </input></form>
# <form method="POST" name="multisat">
# Your tracking list is empty
#   <input name="remove" type="hidden">
# </input></form>
# <script>
# function doit(n)
# {
#  document.multisat.remove.value=n;
#  document.multisat.submit();
# }
# </script> </center>
# </td>
# </tr>
# </table>
# <br/>
# <div id="medianetsatellite">
# <!--<center>
# <a href="//thegreatcoursesplus.7eer.net/c/379891/310092/3896"><img src="//a.impactradius-go.com/display-ad/3896-310092" border="0" alt="" width="300" height="250"/></a><img height="0" width="0" src="//thegreatcoursesplus.7eer.net/i/379891/310092/3896" style="position:absolute;visibility:hidden;" border="0" />
# </center>-->
# </div>
# <center>
# <script>
# 			var norad_n2yo = '39035';
# 			var size_n2yo = 'small';
# 			var allpasses_n2yo = '1';
# 			var map_n2yo = '2';
# 		</script>
# <script src="https://www.n2yo.com/js/widget-tracker.js" type="text/javascript"></script>
# </center>
# <br/>
# <center><script type="text/javascript">
#     google_ad_client = "ca-pub-8839140430005838";
#     google_ad_slot = "4683736009";
#     google_ad_width = 320;
#     google_ad_height = 100;
# </script>
# <!-- 320x100 live streaming -->
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
# </script></center>
# </div>
# <br/>
# <br/><a href="https://nssdc.gsfc.nasa.gov/nmc/spacecraft/display.action?id=2012-075B" target="_blank">NASA's NSSDC Master Catalog</a>
# <a class="showTip nssdc" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/>
# <br/>
# <b>Two Line Element Set (TLE):</b> <a class="showTip tle" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <div id="tle">
# <pre>
# 1 39035U 12075B   25175.47737547 -.00000024  00000-0  00000-0 0  9996
# 2 39035   0.0153  72.5101 0001653  10.4622 246.9530  1.00271761  3464
# </pre>
# 		Source of the keplerian elements: AFSPC		<br/><br/>
# </div>
# </td>
# </tr>
# </table>
# <!-- footer -->
# <div id="footer">
# <table id="footer">
# <!-- Other links-->
# <tr>
# <td align="center">
# <a href="/about/?a=links">Links</a>  <a href="/about/?a=terms">Terms of Use</a>  <a href="/about/?a=privacy">Privacy Policy</a>  <a href="/about/?a=feedback">Contact Us</a>
# <br/>Copyright © N2YO.com. All rights reserved
# <!--<br/><a href="http://www.itprostar.com">Developed by ITPROSTAR</a>-->
# <br/><br/><!-- AddThis Button BEGIN -->
# <a class="addthis_button" href="https://www.addthis.com/bookmark.php?v=250&amp;username=xa-4bfedf760e3dd1ee"><img alt="Bookmark and Share" height="16" src="https://s7.addthis.com/static/btn/v2/lg-share-en.gif" style="border:0" width="125"/></a><script src="https://s7.addthis.com/js/250/addthis_widget.js#username=xa-4bfedf760e3dd1ee" type="text/javascript"></script>
# <!-- AddThis Button END -->
# </td>
# </tr>
# </table>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-330684-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <!--<script type="text/javascript">
#     var infolink_pid = 1099291;
#     var infolink_wsid = 0;
# </script>
# <script type="text/javascript" src="http://resources.infolinks.com/js/infolinks_main.js"></script>-->
# </div>
# <!--
# -->
# </body>

# %%
br_tags= soup.find_all("br")
for i in br_tags:
    print(i)
# Out:
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br>
# <b>NORAD ID</b>: 39035 <a class="showTip noradid" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Int'l Code</b>: 2012-075B <a class="showTip intlcode" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Perigee</b>: 35,786.8 km <a class="showTip perigee" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Apogee</b>: 35,800.7 km <a class="showTip apogee" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Inclination</b>: 0.0 ° <a class="showTip inclination" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Period</b>: 1,436.1 minutes <a class="showTip period" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Semi major axis</b>: 42164 km <a class="showTip semimajoraxis" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>RCS</b>: 4.6929 m<sup>2</sup> (large) <a class="showTip rcs" href="#"><img alt="" border="0" height="12" src="../img/info.png" width="12"/></a>
# <br/><b>Launch date</b>: <a href="/browse/?y=2012&amp;m=12">December 19, 2012</a>
# <br/><b>Source</b>: Mexico (MEX)
# 			<br/><b>Launch site</b>: FRENCH GUIANA (FRGUI)
#
#
#
#
#
#
#
#
# 									<br/><br/>Mexsat Bicentenario, also named Mexsat 3, will provide fixed communications services with 12 active C-band and 12 active Ku-band transponders. From its operating post at 114.9 degrees west longitude, the satellite's communications payload will reach users across Mexico and surrounding waters. Boeing is building two larger satellites tailored for mobile communications services. The Mexsat system is expected to be in service until 2028. Mexsat Bicentenario is based on Orbital's GEOStar 2 satellite bus. It will enter service in 2013, beaming broadband Internet, telephone, telemedicine, education and videoconferencing across Mexico. It will also reach rural communities not served by existing infrastructure. The Mexsat system will aid Mexican government officials in disaster response and national security applications, according to the Mexican Ministry of Communications and Transportation.
#
# 		</br>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %%
str_br_tags=br_tags[7].text
print(str_br_tags)
# Out:
# NORAD ID: 39035
# Int'l Code: 2012-075B
# Perigee: 35,786.8 km
# Apogee: 35,800.7 km
# Inclination: 0.0 °
# Period: 1,436.1 minutes
# Semi major axis: 42164 km
# RCS: 4.6929 m2 (large)
# Launch date: December 19, 2012
# Source: Mexico (MEX)
# 			Launch site: FRENCH GUIANA (FRGUI)
#
#
#
#
#
#
#
#
# 									Mexsat Bicentenario, also named Mexsat 3, will provide fixed communications services with 12 active C-band and 12 active Ku-band transponders. From its operating post at 114.9 degrees west longitude, the satellite's communications payload will reach users across Mexico and surrounding waters. Boeing is building two larger satellites tailored for mobile communications services. The Mexsat system is expected to be in service until 2028. Mexsat Bicentenario is based on Orbital's GEOStar 2 satellite bus. It will enter service in 2013, beaming broadband Internet, telephone, telemedicine, education and videoconferencing across Mexico. It will also reach rural communities not served by existing infrastructure. The Mexsat system will aid Mexican government officials in disaster response and national security applications, according to the Mexican Ministry of Communications and Transportation.

# %%
import re

pattern_finded= re.findall(r"Perigee:\s\d+,\d+.\d+\skm\s\sApogee: \d+,\d+.\d+\skm", str_br_tags)
#print(pattern_searched)
print(pattern_finded)
for i in pattern_finded:
    print(i)

str_pattern_finded= str(pattern_finded)
print(str_pattern_finded)
str_Perigee= str_pattern_finded[10:20]
str_Apogee= str_pattern_finded[32:42]

print(str_Perigee)
print(str_Apogee)

str_Perigee = str_Perigee.replace(",", "")
print(str_Perigee)

str_Apogee = str_Apogee.replace(",", "")
print(str_Apogee)

print(float(str_Perigee))
print(float(str_Apogee))
# Out:
# ['Perigee: 35,786.8 km \nApogee: 35,800.7 km']
# Perigee: 35,786.8 km
# Apogee: 35,800.7 km
# ['Perigee: 35,786.8 km \nApogee: 35,800.7 km']
#  35,786.8
#  35,800.7
#  35786.8
#  35800.7
# 35786.8
# 35800.7

# %%
#Perigee:\s\d\d,\d\d\d\.\d\skm\s\s[A-Za-z]+: \d\d,\d\d\d\.\d\s[A-Za-z]+
#Perigee:\s\d+,\d+.\d+\skm\s\sApogee: \d+,\d+.\d+\skm

# %%
import re

test= """NORAD ID: 39035 
Int'l Code: 2012-075B 
Perigee: 35,786.8 km 
Apogee: 35,800.7 km 
Inclination: 0.0 ° 
Period: 1,436.1 minutes 
Semi major axis: 42164 km 
RCS: 4.6929 m2 (large) 
Launch date: December 19, 2012
Source: Mexico (MEX)"""

#print(test)

pattern_finded= re.findall(r"Perigee:\s\d+,\d+.\d+\skm\s\sApogee: \d+,\d+.\d+\skm", test)

print(pattern_finded)
# Out:
# ['Perigee: 35,786.8 km \nApogee: 35,800.7 km']

# %% [markdown]
# # Creating the function to find Apogee and Perigee

# %%
import re
import requests
from bs4 import BeautifulSoup as bs
from requests.packages.urllib3.exceptions import InsecureRequestWarning


requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

def getting_Perigee_Apogee(i):
    page = requests.get('https://www.n2yo.com/satellite/?s='+str(i)+'#results', verify=False) #39035, 40025
    #print(page)
    #print(page.content)
    soup = bs(page.text, 'html.parser')
    #print(soup)

    td_tags= soup.find_all("td")
    #print(td_tags)

    str_td_tags=str(td_tags)
    #print(str_br_tags)

    pattern_finded_Perigee= re.findall(r"<b>Perigee</b>:\s.+.\d+\skm", str_td_tags) 
    pattern_finded_Apogee= re.findall(r"<b>Apogee</b>:\s.+\d+.\d+\skm", str_td_tags)
    print(pattern_finded_Perigee)
    #print(len(pattern_finded_Perigee))
    #print(pattern_finded_Apogee)

    if len(pattern_finded_Perigee) > 0 and len(pattern_finded_Apogee) > 0:
    
        str_Perigee= pattern_finded_Perigee[0]
        str_Apogee= pattern_finded_Apogee[0]
        #print(str_Perigee)
        #print(str_Apogee)
        str_Perigee= str_Perigee[15:-2]
        str_Apogee= str_Apogee[14:-2]

        #print(str_Perigee)
        #print(str_Apogee)

        if len(str_Perigee) > 7:
            str_Perigee = str_Perigee.replace(",", "")
            #print(str_Perigee)
        if len(str_Apogee) > 7:
            str_Apogee = str_Apogee.replace(",", "")
            #print(str_Apogee)

        #print(float(str_Perigee))
        #print(float(str_Apogee))

        lim_sup= 35836.0
        lim_inf= 35736.0

        if float(str_Perigee) <= lim_sup and float(str_Perigee) >= lim_inf:
            write= str(i)+"\nPerigee: "+str_Perigee+"\nApogee: "+str_Apogee
            textfile= open("C:\\Users\\Joel\\Documents\\Python\\email\\Perigee_Apogee_Range.txt", "a")
            textfile.write(write+"\n\n")
            textfile.close()
            #print("Apendeamos por Perigee")
        elif float(str_Apogee) <= lim_sup and float(str_Apogee) >= lim_inf:
            write= str(i)+"\nPerigee: "+str_Perigee+"\nApogee: "+str_Apogee
            textfile= open("C:\\Users\\Joel\\Documents\\Python\\email\\Perigee_Apogee_Range.txt", "a")
            textfile.write(write+"\n\n")
            textfile.close()
            #print("Apendeamos por Apogee")
        elif float(str_Apogee) >= lim_sup and float(str_Perigee) <= lim_inf:
            write= str(i)+"\nPerigee: "+str_Perigee+"\nApogee: "+str_Apogee
            textfile= open("C:\\Users\\Joel\\Documents\\Python\\email\\Perigee_Apogee_Range.txt", "a")
            textfile.write(write+"\n\n")
            textfile.close()
            #print("Apendeamos porque cruza Radio Geostacionario")

# %%
getting_Perigee_Apogee(64394) #26410, 40025, 39035, 64394
# Out:
# ['<b>Perigee</b>: 31,222.7 km']
# ['<b>Apogee</b>: 36,118.7 km']

# %%
for i in range(69963, 100000):
    print(i)
    getting_Perigee_Apogee(i)

# %%
import re
string="<b>Perigee</b>: 35,786.8 km"

pattern_finded= re.findall(r"<b>Perigee</b>:\s.+.\d+\skm", string) #<b>Perigee</b>: 35,786.8 km #\s\sApogee: \d+.\d+\skm

print(pattern_finded)
# Out:
# ['<b>Perigee</b>: 786.8 km']

# %%
ProxyError: HTTPSConnectionPool(host='www.n2yo.com', port=443): Max retries exceeded with url: /satellite/?s=34374 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
